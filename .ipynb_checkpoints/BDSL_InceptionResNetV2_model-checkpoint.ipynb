# %%
# importing libraries 
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
from tensorflow.keras.models import Sequential, save_model, load_model
import numpy as np
from tensorflow.keras.callbacks import TensorBoard
import time
import matplotlib.pyplot as plt
import datetime
import cv2
import os
import tensorflow as tf
import tensorflow.keras
import cv2
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

import tensorflow as tf
from keras.utils import np_utils
from tensorflow.keras import applications
import cv2 
from os import listdir
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten, Activation, AveragePooling2D,BatchNormalization
from tensorflow.keras.models import Model
import pywt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
import random
import seaborn as sns
import cv2
import os

from pathlib import Path
from tensorflow.keras.utils import to_categorical
from collections import Counter
from plotly.subplots import make_subplots
from tensorflow.keras.layers.experimental import preprocessing as ps
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import pickle
import glob
print('tf version', tf.__version__)
print('keras version', tf.keras.__version__)
print('gpu is ','available' if tf.config.list_physical_devices('GPU') else 'not available')
# Out:
# tf version 2.8.0
# keras version 2.8.0
# gpu is  available

# %%
file = open('X_train_80.pkl', 'rb')
X_train = pickle.load(file)

file = open('y_train_80.pkl', 'rb')
y_train = pickle.load(file)

file = open('X_test_80.pkl', 'rb')
X_test = pickle.load(file)

file = open('y_test_80.pkl', 'rb')
y_test = pickle.load(file)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (11774, 80, 80, 3)
# (11774, 49)
# (2940, 80, 80, 3)
# (2940, 49)

# %% [markdown]
# # Inception Model 92%

# %%
base_model = tf.keras.applications.InceptionResNetV2(
    include_top=False,
    weights="imagenet",
    input_shape=(80, 80, 3),
    pooling='max',
    classes=49,
    classifier_activation="softmax",
)

# %%
num_of_class = 49
epoch = 30

model = Sequential()
model.add(base_model)
model.add(Dense(128,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_of_class, activation='softmax'))

model.compile(loss ='categorical_crossentropy', optimizer ='adam', metrics =['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_resnet_v2 (Functi  (None, 1536)             54336736
#  onal)
#
#  dense (Dense)               (None, 128)               196736
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_2 (Dense)             (None, 49)                3185
#
# =================================================================
# Total params: 54,544,913
# Trainable params: 54,484,369
# Non-trainable params: 60,544
# _________________________________________________________________

# %%
H = model.fit(
    x=X_train,
    y=y_train,
    batch_size=58,
    epochs=epoch,
    validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 184/184 [==============================] - 61s 241ms/step - loss: 2.0019 - accuracy: 0.4726 - val_loss: 65.1092 - val_accuracy: 0.0313
# Epoch 2/50
# 184/184 [==============================] - 40s 215ms/step - loss: 0.4346 - accuracy: 0.8781 - val_loss: 1.0394 - val_accuracy: 0.8000
# Epoch 3/50
# 184/184 [==============================] - 39s 214ms/step - loss: 0.2205 - accuracy: 0.9380 - val_loss: 0.7429 - val_accuracy: 0.8653
# Epoch 4/50
# 184/184 [==============================] - 39s 214ms/step - loss: 0.1509 - accuracy: 0.9594 - val_loss: 1.0370 - val_accuracy: 0.8078
# Epoch 5/50
# 184/184 [==============================] - 39s 210ms/step - loss: 0.1578 - accuracy: 0.9578 - val_loss: 0.8901 - val_accuracy: 0.8473
# Epoch 6/50
# 184/184 [==============================] - 39s 210ms/step - loss: 0.0871 - accuracy: 0.9773 - val_loss: 0.6067 - val_accuracy: 0.8997
# Epoch 7/50
# 184/184 [==============================] - 39s 211ms/step - loss: 0.0831 - accuracy: 0.9789 - val_loss: 0.5884 - val_accuracy: 0.9156
# Epoch 8/50
# 184/184 [==============================] - 39s 210ms/step - loss: 0.1035 - accuracy: 0.9740 - val_loss: 0.8219 - val_accuracy: 0.8799
# Epoch 9/50
# 184/184 [==============================] - 39s 210ms/step - loss: 0.1040 - accuracy: 0.9716 - val_loss: 0.8928 - val_accuracy: 0.8476
# Epoch 10/50
# 184/184 [==============================] - 39s 210ms/step - loss: 0.0970 - accuracy: 0.9774 - val_loss: 0.5107 - val_accuracy: 0.9031
# Epoch 11/50
# 184/184 [==============================] - 39s 210ms/step - loss: 0.0756 - accuracy: 0.9830 - val_loss: 0.8221 - val_accuracy: 0.8738
# Epoch 12/50
# 184/184 [==============================] - 39s 210ms/step - loss: 0.0953 - accuracy: 0.9771 - val_loss: 0.6379 - val_accuracy: 0.9143
# Epoch 13/50
# 184/184 [==============================] - 39s 210ms/step - loss: 0.0526 - accuracy: 0.9866 - val_loss: 0.7929 - val_accuracy: 0.8881
# Epoch 14/50
# 184/184 [==============================] - 39s 210ms/step - loss: 0.0566 - accuracy: 0.9878 - val_loss: 0.5678 - val_accuracy: 0.9160
# Epoch 15/50
# 184/184 [==============================] - 39s 210ms/step - loss: 0.0360 - accuracy: 0.9910 - val_loss: 0.5788 - val_accuracy: 0.9286
# Epoch 16/50
# 184/184 [==============================] - 39s 210ms/step - loss: 0.
loss: 0.0075 - accuracy: 0.9980 - val_loss: 0.7506 - val_accuracy: 0.9245
# Epoch 44/50
# 184/184 [==============================] - 38s 209ms/step - loss: 0.0619 - accuracy: 0.9877 - val_loss: 0.6956 - val_accuracy: 0.8718
# Epoch 45/50
# 184/184 [==============================] - 39s 209ms/step - loss: 0.0331 - accuracy: 0.9926 - val_loss: 0.6411 - val_accuracy: 0.9313
# Epoch 46/50
# 184/184 [==============================] - 39s 210ms/step - loss: 0.0153 - accuracy: 0.9963 - val_loss: 0.6430 - val_accuracy: 0.9224
# Epoch 47/50
# 184/184 [==============================] - 39s 210ms/step - loss: 0.0198 - accuracy: 0.9952 - val_loss: 1.1288 - val_accuracy: 0.8810
# Epoch 48/50
# 184/184 [==============================] - 39s 210ms/step - loss: 0.0479 - accuracy: 0.9900 - val_loss: 0.5468 - val_accuracy: 0.9296
# Epoch 49/50
# 184/184 [==============================] - 39s 210ms/step - loss: 0.0184 - accuracy: 0.9958 - val_loss: 0.5948 - val_accuracy: 0.9299
# Epoch 50/50
# 184/184 [==============================] - 39s 210ms/step - loss: 0.0248 - accuracy: 0.9941 - val_loss: 0.6755 - val_accuracy: 0.9201

# %% [markdown]
# ### Inception Model Accuracy and loss visualization

# %%
# Plot training & validation accuracy values
fig, ax = plt.subplots(1,1)
plt.plot(H.history["accuracy"])
plt.plot(H.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
fig, ax = plt.subplots(1,1)
plt.plot(H.history['loss'])
plt.plot(H.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ### Model evaluation with classification report and confusion matrix

# %%
y_pred = np.argmax(model.predict(X_test,batch_size=1), axis=1) 

print('Classification Report')
y_classes = [np.argmax(y, axis=None, out=None) for y in y_test]
report = classification_report(y_classes, y_pred)
print(report)

plt.figure(figsize=(30,30))
cm = confusion_matrix(y_classes, y_pred)
_=sns.heatmap(cm.T, annot=True, fmt='d', cbar=True, square=True)
plt.xlabel('Truth')
plt.ylabel('Predicted')
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.86      0.90      0.88        60
#            1       0.97      0.95      0.96        60
#            2       0.98      0.95      0.97        60
#            3       0.71      0.88      0.79        60
#            4       0.88      0.82      0.84        60
#            5       0.90      0.75      0.82        60
#            6       0.96      0.88      0.92        60
#            7       0.94      1.00      0.97        60
#            8       0.97      1.00      0.98        60
#            9       0.92      1.00      0.96        60
#           10       0.98      0.97      0.97        60
#           11       0.92      0.97      0.94        60
#           12       1.00      0.98      0.99        60
#           13       0.97      1.00      0.98        60
#           14       0.97      0.97      0.97        60
#           15       0.81      0.98      0.89        60
#           16       1.00      0.90      0.95        60
#           17       0.97      0.95      0.96        60
#           18       0.92      0.80      0.86        60
#           19       0.97      0.98      0.98        60
#           20       0.74      0.95      0.83        60
#           21       0.95      0.92      0.93        60
#           22       0.98      0.90      0.94        60
#           23       0.98      1.00      0.99        60
#           24       1.00      0.90      0.95        60
#           25       1.00      0.93      0.97        60
#           26       0.92      0.92      0.92        60
#           27       1.00      0.98      0.99        60
#           28       0.78      0.85      0.82        60
#           29       0.92      1.00      0.96        60
#           30       0.90      0.75      0.82        60
#           31       0.98      1.00      0.99        60
#           32       0.98      1.00      0.99        60
#           33       0.93      0.68      0.79        60
#           34       0.91      1.00      0.95        60
#           35       1.00      1.00      1.00        60
#           36       1.00      1.00      1.00        60
#           37       1.00      0.97      0.98        60
#           38       1.00      0.97      0.98        60
#           39       0.98      0.93      0.96        60
#           40       0.98      1.00      0.99        60
#           41       1.00      0.98      0.99        60
#           42       0.89      0.97      0.93        60
#           43       0.00      0.00      0.00        60
#           44       0.47      0.95      0.63        60
#           45       0.98      1.00      0.99        60
#           46       0.95      0.97      0.96        60
#           47       1.00      0.95      0.97        60
#           48       1.00      0.98      0.99        60
#
#     accuracy                           0.92      2940
#    macro avg       0.91      0.92      0.91      2940
# weighted avg       0.91      0.92      0.91      2940
# Text(249.0, 0.5, 'Predicted')

# %%
#model.save('./BDSL_model.hdf5')
