# %%
# importing libraries 
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
from tensorflow.keras.models import Sequential, save_model, load_model
import numpy as np
from tensorflow.keras.callbacks import TensorBoard
import time
import matplotlib.pyplot as plt
import datetime
import cv2
import os
import tensorflow as tf
import tensorflow.keras
import cv2
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

import tensorflow as tf
from keras.utils import np_utils
from tensorflow.keras import applications
import cv2 
from os import listdir
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten, Activation, AveragePooling2D,BatchNormalization
from tensorflow.keras.models import Model
import pywt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
import random
import seaborn as sns
import cv2
import os

from pathlib import Path
from tensorflow.keras.utils import to_categorical
from collections import Counter
from plotly.subplots import make_subplots
from tensorflow.keras.layers.experimental import preprocessing as ps
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import pickle
import glob
print('tf version', tf.__version__)
print('keras version', tf.keras.__version__)
print('gpu is ','available' if tf.config.list_physical_devices('GPU') else 'not available')
# Out:
# tf version 2.8.0
# keras version 2.8.0
# gpu is  available

# %%
file = open('X_train_80.pkl', 'rb')
X_train = pickle.load(file)

file = open('y_train_80.pkl', 'rb')
y_train = pickle.load(file)

file = open('X_test_80.pkl', 'rb')
X_test = pickle.load(file)

file = open('y_test_80.pkl', 'rb')
y_test = pickle.load(file)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (11774, 80, 80, 3)
# (11774, 49)
# (2940, 80, 80, 3)
# (2940, 49)

# %% [markdown]
# # ResNet50V2 Model 86%

# %%
base_model = tf.keras.applications.ResNet50V2(
    include_top=False,
    weights="imagenet",
    input_shape=(80, 80, 3),
    pooling='max',
    classes=49,
    classifier_activation="softmax",
)

# %%
num_of_class = 49
epoch = 30

model = Sequential()
model.add(base_model)
model.add(Dense(128,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_of_class, activation='softmax'))

model.compile(loss ='categorical_crossentropy', optimizer ='adam', metrics =['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50v2 (Functional)     (None, 2048)              23564800
#
#  dense (Dense)               (None, 128)               262272
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_2 (Dense)             (None, 49)                3185
#
# =================================================================
# Total params: 23,838,513
# Trainable params: 23,793,073
# Non-trainable params: 45,440
# _________________________________________________________________

# %%
H = model.fit(
    x=X_train,
    y=y_train,
    batch_size=58,
    epochs=epoch,
    validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 184/184 [==============================] - 31s 137ms/step - loss: 2.1239 - accuracy: 0.4349 - val_loss: 2.2642 - val_accuracy: 0.5095
# Epoch 2/50
# 184/184 [==============================] - 23s 125ms/step - loss: 0.6989 - accuracy: 0.8062 - val_loss: 2.4351 - val_accuracy: 0.4932
# Epoch 3/50
# 184/184 [==============================] - 24s 128ms/step - loss: 0.3963 - accuracy: 0.8865 - val_loss: 0.9946 - val_accuracy: 0.7541
# Epoch 4/50
# 184/184 [==============================] - 23s 124ms/step - loss: 0.2599 - accuracy: 0.9225 - val_loss: 1.7447 - val_accuracy: 0.6374
# Epoch 5/50
# 184/184 [==============================] - 23s 124ms/step - loss: 0.2220 - accuracy: 0.9380 - val_loss: 0.8177 - val_accuracy: 0.8156
# Epoch 6/50
# 184/184 [==============================] - 23s 125ms/step - loss: 0.1661 - accuracy: 0.9527 - val_loss: 0.9028 - val_accuracy: 0.8150
# Epoch 7/50
# 184/184 [==============================] - 23s 125ms/step - loss: 0.1289 - accuracy: 0.9653 - val_loss: 0.8746 - val_accuracy: 0.7986
# Epoch 8/50
# 184/184 [==============================] - 23s 127ms/step - loss: 0.1380 - accuracy: 0.9642 - val_loss: 1.3646 - val_accuracy: 0.7520
# Epoch 9/50
# 184/184 [==============================] - 23s 127ms/step - loss: 0.1060 - accuracy: 0.9712 - val_loss: 1.5709 - val_accuracy: 0.6493
# Epoch 10/50
# 184/184 [==============================] - 23s 127ms/step - loss: 0.1014 - accuracy: 0.9734 - val_loss: 1.3232 - val_accuracy: 0.7480
# Epoch 11/50
# 184/184 [==============================] - 23s 128ms/step - loss: 0.1161 - accuracy: 0.9701 - val_loss: 1.0215 - val_accuracy: 0.8031
# Epoch 12/50
# 184/184 [==============================] - 23s 124ms/step - loss: 0.0924 - accuracy: 0.9750 - val_loss: 0.9954 - val_accuracy: 0.8207
# Epoch 13/50
# 184/184 [==============================] - 23s 124ms/step - loss: 0.0817 - accuracy: 0.9798 - val_loss: 0.6487 - val_accuracy: 0.8677
# Epoch 14/50
# 184/184 [==============================] - 23s 124ms/step - loss: 0.0777 - accuracy: 0.9792 - val_loss: 0.8732 - val_accuracy: 0.8000
# Epoch 15/50
# 184/184 [==============================] - 23s 124ms/step - loss: 0.0771 - accuracy: 0.9811 - val_loss: 0.8040 - val_accuracy: 0.8520
# Epoch 16/50
# 184/184 [==============================] - 23s 124ms/step - loss: 0.1002 - accuracy: 0.9744 - val_loss: 1.4706 - val_accuracy: 0.6806
# Epoch 17/50
# 184/184 [==============================] - 23s 124ms/step - loss: 0.0652 - accuracy: 0.9846 - val_loss: 0.7843 - val_accuracy: 0.8490
# Epoch 18/50
# 184/184 [==============================] - 23s 124ms/step - loss: 0.0543 - accuracy: 0.9879 - val_loss: 0.7850 - val_accuracy: 0.8568
# Epoch 19/50
# 184/184 [==============================] - 23s 126ms/step - loss: 0.0430 - accuracy: 0.9895 - val_loss: 0.6205 - val_accuracy: 0.8881
# Epoch 20/50
# 184/184 [==============================] - 24s 128ms/step - loss: 0.0538 - accuracy: 0.9856 - val_loss: 0.9982 - val_accuracy: 0.8024
# Epoch 21/50
# 184/184 [==============================] - 23s 126ms/step - loss: 0.0489 - accuracy: 0.9882 - val_loss: 0.8944 - val_accuracy: 0.8497
# Epoch 22/50
# 184/184 [==============================] - 23s 126ms/step - loss: 0.0714 - accuracy: 0.9838 - val_loss: 1.0610 - val_accuracy: 0.7789
# Epoch 23/50
# 184/184 [==============================] - 23s 124ms/step - loss: 0.0464 - accuracy: 0.9885 - val_loss: 1.4214 - val_accuracy: 0.7534
# Epoch 24/50
# 184/184 [==============================] - 23s 124ms/step - loss: 0.0450 - accuracy: 0.9901 - val_loss: 0.9941 - val_accuracy: 0.8211
# Epoch 25/50
# 184/184 [==============================] - 23s 125ms/step - loss: 0.0613 - accuracy: 0.9857 - val_loss: 0.8940 - val_accuracy: 0.8163
# Epoch 26/50
# 184/184 [==============================] - 23s 124ms/step - loss: 0.0561 - accuracy: 0.9873 - val_loss: 0.7547 - val_accuracy: 0.8874
# Epoch 27/50
# 184/184 [==============================] - 23s 124ms/step - loss: 0.0496 - accuracy: 0.9880 - val_loss: 0.8778 - val_accuracy: 0.8833
# Epoch 28/50
# 184/184 [==============================] - 23s 124ms/step - loss: 0.0356 - accuracy: 0.9926 - val_loss: 0.7971 - val_accuracy: 0.8949
# Epoch 29/50
# 184/184 [==============================] - 23s 127ms/step - loss: 0.0531 - accuracy: 0.9865 - val_loss: 0.9466 - val_accuracy: 0.8432
# Epoch 30/50
# 184/184 [==============================] - 24s 129ms/step - loss: 0.0628 - accuracy: 0.9851 - val_loss: 0.9052 - val_accuracy: 0.8738
# Epoch 31/50
# 184/184 [==============================] - 23s 127ms/step - loss: 0.0318 - accuracy: 0.9918 - val_loss: 1.0124 - val_accuracy: 0.8361
# Epoch 32/50
# 184/184 [==============================] - 23s 124ms/step - loss: 0.0324 - accuracy: 0.9926 - val_loss: 0.7767 - val_accuracy: 0.8677
# Epoch 33/50
# 184/184 [==============================] - 23s 126ms/step - loss: 0.0244 - accuracy: 0.9944 - val_loss: 1.0537 - val_accuracy: 0.8020
# Epoch 34/50
# 184/184 [==============================] - 23s 126ms/step - loss: 0.0263 - accuracy: 0.9940 - val_loss: 1.3978 - val_accuracy: 0.7551
# Epoch 35/50
# 184/184 [==============================] - 24s 129ms/step - loss: 0.0376 - accuracy: 0.9901 - val_loss: 0.8671 - val_accuracy: 0.8690
# Epoch 36/50
# 184/184 [==============================] - 23s 126ms/step - loss: 0.0587 - accuracy: 0.9866 - val_loss: 0.8902 - val_accuracy: 0.8422
# Epoch 37/50
# 184/184 [==============================] - 23s 127ms/step - loss: 0.0419 - accuracy: 0.9902 - val_loss: 1.0594 - val_accuracy: 0.8085
# Epoch 38/50
# 184/184 [==============================] - 23s 125ms/step - loss: 0.0400 - accuracy: 0.9902 - val_loss: 1.4354 - val_accuracy: 0.7973
# Epoch 39/50
# 184/184 [==============================] - 23s 124ms/step - loss: 0.0353 - accuracy: 0.9915 - val_loss: 0.9952 - val_accuracy: 0.8170
# Epoch 40/50
# 184/184 [==============================] - 23s 124ms/step - loss: 0.0210 - accuracy: 0.9939 - val_loss: 0.7836 - val_accuracy: 0.8820
# Epoch 41/50
# 184/184 [==============================] - 23s 124ms/step - loss: 0.0290 - accuracy: 0.9934 - val_loss: 1.4302 - val_accuracy: 0.6990
# Epoch 42/50
# 184/184 [==============================] - 23s 124ms/step - loss: 0.0222 - accuracy: 0.9954 - val_loss: 0.9106 - val_accuracy: 0.8816
# Epoch 43/50
# 184/184 [==============================] - 23s 124ms/step - loss: 0.0241 - accuracy: 0.9944 - val_loss: 1.4808 - val_accuracy: 0.7279
# Epoch 44/50
# 184/184 [==============================] - 23s 124ms/step - loss: 0.0246 - accuracy: 0.9935 - val_loss: 0.9593 - val_accuracy: 0.8568
# Epoch 45/50
# 184/184 [==============================] - 23s 124ms/step - loss: 0.0382 - accuracy: 0.9920 - val_loss: 1.1537 - val_accuracy: 0.8150
# Epoch 46/50
# 184/184 [==============================] - 23s 123ms/step - loss: 0.0333 - accuracy: 0.9927 - val_loss: 1.4077 - val_accuracy: 0.7378
# Epoch 47/50
# 184/184 [==============================] - 23s 123ms/step - loss: 0.0188 - accuracy: 0.9952 - val_loss: 1.1803 - val_accuracy: 0.8248
# Epoch 48/50
# 184/184 [==============================] - 23s 124ms/step - loss: 0.0626 - accuracy: 0.9862 - val_loss: 1.6477 - val_accuracy: 0.7384
# Epoch 49/50
# 184/184 [==============================] - 23s 124ms/step - loss: 0.0420 - accuracy: 0.9898 - val_loss: 0.9530 - val_accuracy: 0.8605
# Epoch 50/50
# 184/184 [==============================] - 23s 123ms/step - loss: 0.0427 - accuracy: 0.9898 - val_loss: 0.8903 - val_accuracy: 0.8636

# %% [markdown]
# ### ResNet50V2 Model Accuracy and loss visualization

# %%
# Plot training & validation accuracy values
fig, ax = plt.subplots(1,1)
plt.plot(H.history["accuracy"])
plt.plot(H.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
fig, ax = plt.subplots(1,1)
plt.plot(H.history['loss'])
plt.plot(H.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ### Model evaluation with classification report and confusion matrix

# %%
y_pred = np.argmax(model.predict(X_test,batch_size=1), axis=1) 

print('Classification Report')
y_classes = [np.argmax(y, axis=None, out=None) for y in y_test]
report = classification_report(y_classes, y_pred)
print(report)

plt.figure(figsize=(30,30))
cm = confusion_matrix(y_classes, y_pred)
_=sns.heatmap(cm.T, annot=True, fmt='d', cbar=True, square=True)
plt.xlabel('Truth')
plt.ylabel('Predicted')
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.86      0.82      0.84        60
#            1       0.93      0.90      0.92        60
#            2       0.81      0.95      0.88        60
#            3       0.80      0.78      0.79        60
#            4       0.81      0.73      0.77        60
#            5       0.81      0.65      0.72        60
#            6       0.93      0.72      0.81        60
#            7       0.88      0.97      0.92        60
#            8       0.81      0.97      0.88        60
#            9       0.88      1.00      0.94        60
#           10       0.94      0.98      0.96        60
#           11       0.89      0.83      0.86        60
#           12       0.94      0.97      0.95        60
#           13       0.95      0.87      0.90        60
#           14       0.96      0.83      0.89        60
#           15       0.61      1.00      0.76        60
#           16       0.94      0.85      0.89        60
#           17       0.98      0.82      0.89        60
#           18       0.80      0.85      0.82        60
#           19       0.88      0.97      0.92        60
#           20       0.84      0.97      0.90        60
#           21       0.91      0.88      0.90        60
#           22       0.96      0.72      0.82        60
#           23       0.88      0.93      0.90        60
#           24       0.98      0.87      0.92        60
#           25       0.94      1.00      0.97        60
#           26       0.78      0.97      0.87        60
#           27       0.83      0.98      0.90        60
#           28       0.72      0.55      0.62        60
#           29       0.70      0.82      0.75        60
#           30       0.74      0.67      0.70        60
#           31       0.92      0.97      0.94        60
#           32       0.98      0.95      0.97        60
#           33       0.89      0.65      0.75        60
#           34       0.88      0.95      0.91        60
#           35       0.95      0.93      0.94        60
#           36       0.92      0.98      0.95        60
#           37       0.89      0.97      0.93        60
#           38       1.00      0.93      0.97        60
#           39       0.96      0.87      0.91        60
#           40       0.93      0.90      0.92        60
#           41       0.93      0.92      0.92        60
#           42       0.87      0.88      0.88        60
#           43       0.12      0.02      0.03        60
#           44       0.44      0.80      0.57        60
#           45       1.00      0.97      0.98        60
#           46       0.95      0.93      0.94        60
#           47       0.98      0.98      0.98        60
#           48       1.00      0.92      0.96        60
#
#     accuracy                           0.86      2940
#    macro avg       0.86      0.86      0.86      2940
# weighted avg       0.86      0.86      0.86      2940
# Text(249.0, 0.5, 'Predicted')

# %%
#model.save('./BDSL_model.hdf5')
