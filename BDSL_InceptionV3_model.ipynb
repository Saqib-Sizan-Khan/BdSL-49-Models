# %%
# importing libraries 
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
from tensorflow.keras.models import Sequential, save_model, load_model
import numpy as np
from tensorflow.keras.callbacks import TensorBoard
import time
import matplotlib.pyplot as plt
import datetime
import cv2
import os
import tensorflow as tf
import tensorflow.keras
import cv2
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

import tensorflow as tf
from keras.utils import np_utils
from tensorflow.keras import applications
import cv2 
from os import listdir
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten, Activation, AveragePooling2D,BatchNormalization
from tensorflow.keras.models import Model
import pywt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
import random
import seaborn as sns
import cv2
import os

from pathlib import Path
from tensorflow.keras.utils import to_categorical
from collections import Counter
from plotly.subplots import make_subplots
from tensorflow.keras.layers.experimental import preprocessing as ps
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import pickle
import glob
print('tf version', tf.__version__)
print('keras version', tf.keras.__version__)
print('gpu is ','available' if tf.config.list_physical_devices('GPU') else 'not available')
# Out:
# tf version 2.8.0
# keras version 2.8.0
# gpu is  available

# %%
file = open('X_train_80.pkl', 'rb')
X_train = pickle.load(file)

file = open('y_train_80.pkl', 'rb')
y_train = pickle.load(file)

file = open('X_test_80.pkl', 'rb')
X_test = pickle.load(file)

file = open('y_test_80.pkl', 'rb')
y_test = pickle.load(file)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (11774, 80, 80, 3)
# (11774, 49)
# (2940, 80, 80, 3)
# (2940, 49)

# %% [markdown]
# # InceptionV3 Model 92%

# %%
base_model = tf.keras.applications.InceptionV3(
    include_top=False,
    weights="imagenet",
    input_shape=(80, 80, 3),
    pooling='max',
    classes=49,
    classifier_activation="softmax",
)

# %%
num_of_class = 49
epoch = 30

model = Sequential()
model.add(base_model)
model.add(Dense(128,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_of_class, activation='softmax'))

model.compile(loss ='categorical_crossentropy', optimizer ='adam', metrics =['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 2048)              21802784
#
#  dense (Dense)               (None, 128)               262272
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_2 (Dense)             (None, 49)                3185
#
# =================================================================
# Total params: 22,076,497
# Trainable params: 22,042,065
# Non-trainable params: 34,432
# _________________________________________________________________

# %%
H = model.fit(
    x=X_train,
    y=y_train,
    batch_size=58,
    epochs=epoch,
    validation_data=(X_test, y_test))
# Out:
# Epoch 1/30
# 203/203 [==============================] - 34s 114ms/step - loss: 3.8057 - accuracy: 0.0365 - val_loss: 3.6484 - val_accuracy: 0.0415
# Epoch 2/30
# 203/203 [==============================] - 19s 93ms/step - loss: 3.2241 - accuracy: 0.0978 - val_loss: 2.9401 - val_accuracy: 0.1259
# Epoch 3/30
# 203/203 [==============================] - 19s 93ms/step - loss: 2.7266 - accuracy: 0.1596 - val_loss: 2.5987 - val_accuracy: 0.2007
# Epoch 4/30
# 203/203 [==============================] - 19s 94ms/step - loss: 2.4187 - accuracy: 0.2175 - val_loss: 2.1346 - val_accuracy: 0.2850
# Epoch 5/30
# 203/203 [==============================] - 19s 94ms/step - loss: 2.0229 - accuracy: 0.2994 - val_loss: 1.9539 - val_accuracy: 0.3177
# Epoch 6/30
# 203/203 [==============================] - 19s 94ms/step - loss: 1.6418 - accuracy: 0.4041 - val_loss: 2.9448 - val_accuracy: 0.3293
# Epoch 7/30
# 203/203 [==============================] - 19s 94ms/step - loss: 1.4109 - accuracy: 0.4665 - val_loss: 1.6745 - val_accuracy: 0.4636
# Epoch 8/30
# 203/203 [==============================] - 19s 94ms/step - loss: 1.2370 - accuracy: 0.5250 - val_loss: 1.1283 - val_accuracy: 0.5711
# Epoch 9/30
# 203/203 [==============================] - 19s 94ms/step - loss: 1.0834 - accuracy: 0.5862 - val_loss: 1.5057 - val_accuracy: 0.5537
# Epoch 10/30
# 203/203 [==============================] - 19s 94ms/step - loss: 1.0781 - accuracy: 0.6101 - val_loss: 6.0764 - val_accuracy: 0.4677
# Epoch 11/30
# 203/203 [==============================] - 19s 94ms/step - loss: 1.1812 - accuracy: 0.5931 - val_loss: 1.7582 - val_accuracy: 0.4993
# Epoch 12/30
# 203/203 [==============================] - 19s 94ms/step - loss: 1.1671 - accuracy: 0.6135 - val_loss: 1.2511 - val_accuracy: 0.6262
# Epoch 13/30
# 203/203 [==============================] - 19s 94ms/step - loss: 0.9541 - accuracy: 0.6850 - val_loss: 0.7334 - val_accuracy: 0.7660
# Epoch 14/30
# 203/203 [==============================] - 19s 94ms/step - loss: 0.7974 - accuracy: 0.7399 - val_loss: 1.1773 - val_accuracy: 0.6833
# Epoch 15/30
# 203/203 [==============================] - 19s 94ms/step - loss: 0.6476 - accuracy: 0.7805 - val_loss: 0.5554 - val_accuracy: 0.8180
# Epoch 16/30
# 203/203 [==============================] - 19s 95ms/step - loss: 0.5156 - accuracy: 0.8265 - val_loss: 0.4959 - val_accuracy: 0.8463
# Epoch 17/30
# 203/203 [==============================] - 19s 94ms/step - loss: 0.4506 - accuracy: 0.8493 - val_loss: 1.3384 - val_accuracy: 0.6622
# Epoch 18/30
# 203/203 [==============================] - 19s 94ms/step - loss: 0.6786 - accuracy: 0.7930 - val_loss: 0.7546 - val_accuracy: 0.8051
# Epoch 19/30
# 203/203 [==============================] - 19s 94ms/step - loss: 0.7052 - accuracy: 0.7908 - val_loss: 3.6170 - val_accuracy: 0.1071
# Epoch 20/30
# 203/203 [==============================] - 19s 94ms/step - loss: 0.6242 - accuracy: 0.8109 - val_loss: 0.5405 - val_accuracy: 0.8412
# Epoch 21/30
# 203/203 [==============================] - 19s 94ms/step - loss: 0.6108 - accuracy: 0.8200 - val_loss: 3.1056 - val_accuracy: 0.2959
# Epoch 22/30
# 203/203 [==============================] - 19s 94ms/step - loss: 0.6943 - accuracy: 0.7960 - val_loss: 0.7645 - val_accuracy: 0.7986
# Epoch 23/30
# 203/203 [==============================] - 19s 94ms/step - loss: 0.5012 - accuracy: 0.8465 - val_loss: 0.5527 - val_accuracy: 0.8364
# Epoch 24/30
# 203/203 [==============================] - 19s 94ms/step - loss: 0.4765 - accuracy: 0.8596 - val_loss: 0.6350 - val_accuracy: 0.8197
# Epoch 25/30
# 203/203 [==============================] - 19s 94ms/step - loss: 0.9145 - accuracy: 0.7568 - val_loss: 3.7855 - val_accuracy: 0.2850
# Epoch 26/30
# 203/203 [==============================] - 19s 94ms/step - loss: 0.8541 - accuracy: 0.7605 - val_loss: 0.7691 - val_accuracy: 0.7789
# Epoch 27/30
# 203/203 [==============================] - 19s 94ms/step - loss: 0.5068 - accuracy: 0.8515 - val_loss: 0.6554 - val_accuracy: 0.8170
# Epoch 28/30
# 203/203 [==============================] - 19s 94ms/step - loss: 0.4332 - accuracy: 0.8722 - val_loss: 0.7781 - val_accuracy: 0.7656
# Epoch 29/30
# 203/203 [==============================] - 19s 94ms/step - loss: 0.3616 - accuracy: 0.8886 - val_loss: 0.3716 - val_accuracy: 0.8980
# Epoch 30/30
# 203/203 [==============================] - 19s 94ms/step - loss: 0.4672 - accuracy: 0.8659 - val_loss: 0.5209 - val_accuracy: 0.8544

# %% [markdown]
# ### InceptionV3 Model Accuracy and loss visualization

# %%
# Plot training & validation accuracy values
fig, ax = plt.subplots(1,1)
plt.plot(H.history["accuracy"])
plt.plot(H.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('accuracy.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Plot training & validation loss values
fig, ax = plt.subplots(1,1)
plt.plot(H.history['loss'])
plt.plot(H.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('foo.png')
plt.show()

# %% [markdown]
# ### Model evaluation with classification report and confusion matrix

# %%
y_pred = np.argmax(model.predict(X_test,batch_size=1), axis=1) 

print('Classification Report')
y_classes = [np.argmax(y, axis=None, out=None) for y in y_test]
report = classification_report(y_classes, y_pred)
print(report)

plt.figure(figsize=(30,30))
cm = confusion_matrix(y_classes, y_pred)
_=sns.heatmap(cm.T, annot=True, fmt='d', cbar=True, square=True)
plt.xlabel('Truth')
plt.ylabel('Predicted')
plt.savefig('CM.png', dpi=300, bbox_inches='tight')
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.80      0.87      0.83        60
#            1       0.84      0.90      0.87        60
#            2       0.90      0.75      0.82        60
#            3       0.73      0.72      0.72        60
#            4       0.70      0.78      0.74        60
#            5       0.92      0.78      0.85        60
#            6       0.94      0.82      0.87        60
#            7       0.95      0.90      0.92        60
#            8       0.95      0.92      0.93        60
#            9       0.85      0.93      0.89        60
#           10       0.94      1.00      0.97        60
#           11       0.89      0.85      0.87        60
#           12       0.94      1.00      0.97        60
#           13       0.94      0.83      0.88        60
#           14       0.87      0.97      0.91        60
#           15       0.84      0.90      0.87        60
#           16       0.95      0.93      0.94        60
#           17       0.83      0.95      0.88        60
#           18       0.71      0.87      0.78        60
#           19       0.98      0.98      0.98        60
#           20       0.91      0.88      0.90        60
#           21       0.81      0.95      0.88        60
#           22       0.94      0.52      0.67        60
#           23       0.97      0.98      0.98        60
#           24       0.96      0.83      0.89        60
#           25       0.89      0.97      0.93        60
#           26       0.94      0.78      0.85        60
#           27       0.88      0.93      0.90        60
#           28       0.39      0.47      0.43        60
#           29       0.60      0.83      0.69        60
#           30       0.57      0.28      0.38        60
#           31       0.96      0.88      0.92        60
#           32       0.98      0.97      0.97        60
#           33       0.79      0.97      0.87        60
#           34       0.88      0.82      0.84        60
#           35       0.98      0.90      0.94        60
#           36       0.72      0.97      0.82        60
#           37       0.80      0.87      0.83        60
#           38       0.82      0.85      0.84        60
#           39       0.81      0.83      0.82        60
#           40       0.89      0.82      0.85        60
#           41       0.96      0.90      0.93        60
#           42       0.83      0.90      0.86        60
#           43       0.79      0.80      0.79        60
#           44       0.88      0.72      0.79        60
#           45       0.88      0.98      0.93        60
#           46       0.98      0.93      0.96        60
#           47       0.93      0.87      0.90        60
#           48       1.00      0.82      0.90        60
#
#     accuracy                           0.85      2940
#    macro avg       0.86      0.85      0.85      2940
# weighted avg       0.86      0.85      0.85      2940

# %%
#model.save('./BDSL_xception_model.hdf5')
