# %%
# importing libraries 
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
from tensorflow.keras.models import Sequential, save_model, load_model
import numpy as np
from tensorflow.keras.callbacks import TensorBoard
import time
import matplotlib.pyplot as plt
import datetime
import cv2
import os
import tensorflow as tf
import tensorflow.keras
import cv2
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

import tensorflow as tf
from keras.utils import np_utils
from tensorflow.keras import applications
import cv2 
from os import listdir
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten, Activation, AveragePooling2D,BatchNormalization
from tensorflow.keras.models import Model
import pywt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
import random
import seaborn as sns
import cv2
import os

from pathlib import Path
from tensorflow.keras.utils import to_categorical
from collections import Counter
from plotly.subplots import make_subplots
from tensorflow.keras.layers.experimental import preprocessing as ps
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import pickle
import glob
print('tf version', tf.__version__)
print('keras version', tf.keras.__version__)
print('gpu is ','available' if tf.config.list_physical_devices('GPU') else 'not available')
# Out:
# tf version 2.8.0
# keras version 2.8.0
# gpu is  available

# %%
file = open('X_train_80.pkl', 'rb')
X_train = pickle.load(file)

file = open('y_train_80.pkl', 'rb')
y_train = pickle.load(file)

file = open('X_test_80.pkl', 'rb')
X_test = pickle.load(file)

file = open('y_test_80.pkl', 'rb')
y_test = pickle.load(file)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (11774, 80, 80, 3)
# (11774, 49)
# (2940, 80, 80, 3)
# (2940, 49)

# %% [markdown]
# # Xception Model

# %%
base_model = tf.keras.applications.Xception(
    include_top=False,
    weights="imagenet",
    input_shape=(80, 80, 3),
    pooling='max',
    classes=49,
    classifier_activation="softmax",
)

#base_model.trainable = False

# %%
num_of_class = 49
epoch = 30

model = Sequential()
model.add(base_model)
model.add(Dense(128,activation='relu'))
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_of_class, activation='softmax'))

model.compile(loss ='categorical_crossentropy', optimizer ='adam', metrics =['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 2048)              20861480
#
#  dense (Dense)               (None, 128)               262272
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_2 (Dense)             (None, 49)                3185
#
# =================================================================
# Total params: 21,135,193
# Trainable params: 21,080,665
# Non-trainable params: 54,528
# _________________________________________________________________

# %%
H = model.fit(
    x=X_train,
    y=y_train,
    batch_size=58,
    epochs=epoch,
    validation_data=(X_test, y_test))
# Out:
# Epoch 1/30
# 203/203 [==============================] - 38s 160ms/step - loss: 2.6682 - accuracy: 0.2942 - val_loss: 2.4870 - val_accuracy: 0.4265
# Epoch 2/30
# 203/203 [==============================] - 32s 155ms/step - loss: 1.0074 - accuracy: 0.6994 - val_loss: 0.8937 - val_accuracy: 0.7680
# Epoch 3/30
# 203/203 [==============================] - 32s 156ms/step - loss: 0.5090 - accuracy: 0.8555 - val_loss: 0.7264 - val_accuracy: 0.8333
# Epoch 4/30
# 203/203 [==============================] - 32s 157ms/step - loss: 0.3435 - accuracy: 0.9039 - val_loss: 0.4972 - val_accuracy: 0.8745
# Epoch 5/30
# 203/203 [==============================] - 32s 159ms/step - loss: 0.3319 - accuracy: 0.9140 - val_loss: 0.3611 - val_accuracy: 0.9105
# Epoch 6/30
# 203/203 [==============================] - 32s 159ms/step - loss: 0.2922 - accuracy: 0.9295 - val_loss: 0.6153 - val_accuracy: 0.8949
# Epoch 7/30
# 203/203 [==============================] - 32s 159ms/step - loss: 0.2155 - accuracy: 0.9482 - val_loss: 0.3325 - val_accuracy: 0.9238
# Epoch 8/30
# 203/203 [==============================] - 32s 158ms/step - loss: 0.1655 - accuracy: 0.9612 - val_loss: 0.3970 - val_accuracy: 0.9105
# Epoch 9/30
# 203/203 [==============================] - 32s 159ms/step - loss: 0.1344 - accuracy: 0.9676 - val_loss: 0.3133 - val_accuracy: 0.9276
# Epoch 10/30
# 203/203 [==============================] - 32s 159ms/step - loss: 0.1477 - accuracy: 0.9643 - val_loss: 0.5750 - val_accuracy: 0.8973
# Epoch 11/30
# 203/203 [==============================] - 32s 159ms/step - loss: 0.1373 - accuracy: 0.9662 - val_loss: 0.5686 - val_accuracy: 0.8976
# Epoch 12/30
# 203/203 [==============================] - 32s 159ms/step - loss: 0.1292 - accuracy: 0.9673 - val_loss: 0.3106 - val_accuracy: 0.9303
# Epoch 13/30
# 203/203 [==============================] - 32s 158ms/step - loss: 0.0841 - accuracy: 0.9802 - val_loss: 0.6190 - val_accuracy: 0.8973
# Epoch 14/30
# 203/203 [==============================] - 32s 159ms/step - loss: 0.1255 - accuracy: 0.9717 - val_loss: 0.3162 - val_accuracy: 0.9330
# Epoch 15/30
# 203/203 [==============================] - 33s 161ms/step - loss: 0.1064 - accuracy: 0.9746 - val_loss: 0.2958 - val_accuracy: 0.9432
# Epoch 16/30
# 203/203 [==============================] - 33s 161ms/step - loss: 0.1472 - accuracy: 0.9718 - val_loss: 0.3886 - val_accuracy: 0.9299
# Epoch 17/30
# 203/203 [==============================] - 33s 161ms/step - loss: 0.1124 - accuracy: 0.9759 - val_loss: 0.4006 - val_accuracy: 0.9248
# Epoch 18/30
# 203/203 [==============================] - 33s 161ms/step - loss: 0.0966 - accuracy: 0.9774 - val_loss: 0.3183 - val_accuracy: 0.9480
# Epoch 19/30
# 203/203 [==============================] - 33s 161ms/step - loss: 0.0593 - accuracy: 0.9868 - val_loss: 0.2018 - val_accuracy: 0.9582
# Epoch 20/30
# 203/203 [==============================] - 33s 160ms/step - loss: 0.1107 - accuracy: 0.9783 - val_loss: 0.5105 - val_accuracy: 0.9150
# Epoch 21/30
# 203/203 [==============================] - 32s 160ms/step - loss: 0.0645 - accuracy: 0.9845 - val_loss: 0.4252 - val_accuracy: 0.9286
# Epoch 22/30
# 203/203 [==============================] - 33s 162ms/step - loss: 0.0893 - accuracy: 0.9823 - val_loss: 0.8039 - val_accuracy: 0.8602
# Epoch 23/30
# 203/203 [==============================] - 33s 161ms/step - loss: 0.0890 - accuracy: 0.9804 - val_loss: 0.2478 - val_accuracy: 0.9517
# Epoch 24/30
# 203/203 [==============================] - 33s 161ms/step - loss: 0.0588 - accuracy: 0.9862 - val_loss: 0.3165 - val_accuracy: 0.9442
# Epoch 25/30
# 203/203 [==============================] - 33s 161ms/step - loss: 0.1219 - accuracy: 0.9750 - val_loss: 0.5878 - val_accuracy: 0.8939
# Epoch 26/30
# 203/203 [==============================] - 33s 164ms/step - loss: 0.0706 - accuracy: 0.9847 - val_loss: 0.2491 - val_accuracy: 0.9486
# Epoch 27/30
# 203/203 [==============================] - 33s 162ms/step - loss: 0.0534 - accuracy: 0.9889 - val_loss: 0.2545 - val_accuracy: 0.9551
# Epoch 28/30
# 203/203 [==============================] - 33s 163ms/step - loss: 0.0574 - accuracy: 0.9879 - val_loss: 0.3224 - val_accuracy: 0.9442
# Epoch 29/30
# 203/203 [==============================] - 33s 163ms/step - loss: 0.0804 - accuracy: 0.9820 - val_loss: 0.3913 - val_accuracy: 0.9354
# Epoch 30/30
# 203/203 [==============================] - 33s 161ms/step - loss: 0.0678 - accuracy: 0.9845 - val_loss: 0.3213 - val_accuracy: 0.9446

# %% [markdown]
# ### Xception Model Accuracy and loss visualization

# %%
# Plot training & validation accuracy values
fig, ax = plt.subplots(1,1)
plt.plot(H.history["accuracy"])
plt.plot(H.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('accuracy.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Plot training & validation loss values
fig, ax = plt.subplots(1,1)
plt.plot(H.history['loss'])
plt.plot(H.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.savefig('loss.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Model evaluation with classification report and confusion matrix

# %%
y_pred = np.argmax(model.predict(X_test,batch_size=1), axis=1) 

print('Classification Report')
y_classes = [np.argmax(y, axis=None, out=None) for y in y_test]
report = classification_report(y_classes, y_pred)
print(report)

plt.figure(figsize=(30,30))
cm = confusion_matrix(y_classes, y_pred)
_=sns.heatmap(cm.T, annot=True, fmt='d', cbar=True, square=True)
plt.xlabel('Truth')
plt.ylabel('Predicted')
plt.savefig('confusion_matrix.png', dpi=300, bbox_inches='tight')
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.61      0.98      0.75        60
#            1       0.97      0.98      0.98        60
#            2       0.90      0.95      0.93        60
#            3       0.87      0.90      0.89        60
#            4       0.85      0.93      0.89        60
#            5       0.93      0.95      0.94        60
#            6       0.92      0.97      0.94        60
#            7       1.00      0.97      0.98        60
#            8       0.98      1.00      0.99        60
#            9       0.87      1.00      0.93        60
#           10       1.00      1.00      1.00        60
#           11       0.96      0.88      0.92        60
#           12       1.00      0.93      0.97        60
#           13       0.89      0.98      0.94        60
#           14       0.92      1.00      0.96        60
#           15       1.00      1.00      1.00        60
#           16       1.00      0.92      0.96        60
#           17       1.00      0.98      0.99        60
#           18       0.98      0.90      0.94        60
#           19       0.98      0.93      0.96        60
#           20       0.97      0.97      0.97        60
#           21       0.83      1.00      0.91        60
#           22       0.95      0.92      0.93        60
#           23       0.98      0.98      0.98        60
#           24       1.00      0.80      0.89        60
#           25       0.98      1.00      0.99        60
#           26       0.94      0.97      0.95        60
#           27       1.00      1.00      1.00        60
#           28       0.90      0.75      0.82        60
#           29       1.00      0.32      0.48        60
#           30       0.80      0.95      0.87        60
#           31       0.94      1.00      0.97        60
#           32       0.98      1.00      0.99        60
#           33       0.94      0.97      0.95        60
#           34       1.00      0.98      0.99        60
#           35       1.00      0.98      0.99        60
#           36       0.98      1.00      0.99        60
#           37       0.97      0.97      0.97        60
#           38       0.97      0.97      0.97        60
#           39       1.00      0.95      0.97        60
#           40       0.95      1.00      0.98        60
#           41       1.00      0.98      0.99        60
#           42       1.00      0.92      0.96        60
#           43       0.97      0.98      0.98        60
#           44       0.96      0.85      0.90        60
#           45       1.00      0.97      0.98        60
#           46       0.98      0.95      0.97        60
#           47       1.00      1.00      1.00        60
#           48       1.00      1.00      1.00        60
#
#     accuracy                           0.94      2940
#    macro avg       0.95      0.94      0.94      2940
# weighted avg       0.95      0.94      0.94      2940

# %%
#model.save('./BDSL_xception_model.hdf5')
