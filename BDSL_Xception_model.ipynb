# %%
# importing libraries 
from tensorflow.keras.preprocessing.image import ImageDataGenerator 
from tensorflow.keras.models import Sequential, save_model, load_model
import numpy as np
from tensorflow.keras.callbacks import TensorBoard
import time
import matplotlib.pyplot as plt
import datetime
import cv2
import os
import tensorflow as tf
import tensorflow.keras
import cv2
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

import tensorflow as tf
from keras.utils import np_utils
from tensorflow.keras import applications
import cv2 
from os import listdir
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, Flatten, Activation, AveragePooling2D,BatchNormalization
from tensorflow.keras.models import Model
import pywt
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px
import random
import seaborn as sns
import cv2
import os

from pathlib import Path
from tensorflow.keras.utils import to_categorical
from collections import Counter
from plotly.subplots import make_subplots
from tensorflow.keras.layers.experimental import preprocessing as ps
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import pickle
import glob
print('tf version', tf.__version__)
print('keras version', tf.keras.__version__)
print('gpu is ','available' if tf.config.list_physical_devices('GPU') else 'not available')
# Out:
# tf version 2.8.0
# keras version 2.8.0
# gpu is  available

# %%
file = open('X_train_128.pkl', 'rb')
X_train = pickle.load(file)

file = open('y_train_128.pkl', 'rb')
y_train = pickle.load(file)

file = open('X_test_128.pkl', 'rb')
X_test = pickle.load(file)

file = open('y_test_128.pkl', 'rb')
y_test = pickle.load(file)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (11774, 128, 128, 3)
# (11774, 49)
# (2940, 128, 128, 3)
# (2940, 49)

# %% [markdown]
# # Xception Model 94%

# %%
base_model = tf.keras.applications.Xception(
    include_top=False,
    weights="imagenet",
    input_shape=(128, 128, 3),
    pooling='max',
    classes=49,
    classifier_activation="softmax",
)

#base_model.trainable = False

# %%
num_of_class = 49
epoch = 50

model = Sequential()
model.add(base_model)
model.add(Dense(128,activation=tf.keras.layers.LeakyReLU()))
model.add(Dense(64,activation=tf.keras.layers.LeakyReLU()))
model.add(Dropout(0.3))
model.add(Dense(num_of_class, activation='softmax'))

model.compile(loss ='categorical_crossentropy', optimizer ='adam', metrics =['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 2048)              20861480
#
#  dense (Dense)               (None, 128)               262272
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout (Dropout)           (None, 64)                0
#
#  dense_2 (Dense)             (None, 49)                3185
#
# =================================================================
# Total params: 21,135,193
# Trainable params: 21,080,665
# Non-trainable params: 54,528
# _________________________________________________________________

# %%
H = model.fit(
    x=X_train,
    y=y_train,
    batch_size=58,
    epochs=epoch,
    validation_data=(X_test, y_test))
# Out:
# Epoch 1/50
# 203/203 [==============================] - 76s 335ms/step - loss: 2.0857 - accuracy: 0.4566 - val_loss: 2.0096 - val_accuracy: 0.5847
# Epoch 2/50
# 203/203 [==============================] - 67s 332ms/step - loss: 0.3477 - accuracy: 0.8983 - val_loss: 0.4267 - val_accuracy: 0.8881
# Epoch 3/50
# 203/203 [==============================] - 68s 334ms/step - loss: 0.2011 - accuracy: 0.9425 - val_loss: 0.2969 - val_accuracy: 0.9224
# Epoch 4/50
# 203/203 [==============================] - 67s 333ms/step - loss: 0.1572 - accuracy: 0.9561 - val_loss: 0.4505 - val_accuracy: 0.8820
# Epoch 5/50
# 203/203 [==============================] - 68s 333ms/step - loss: 0.1139 - accuracy: 0.9708 - val_loss: 0.4320 - val_accuracy: 0.9037
# Epoch 6/50
# 203/203 [==============================] - 68s 333ms/step - loss: 0.0908 - accuracy: 0.9752 - val_loss: 0.3059 - val_accuracy: 0.9361
# Epoch 7/50
# 203/203 [==============================] - 68s 333ms/step - loss: 0.0932 - accuracy: 0.9781 - val_loss: 0.3514 - val_accuracy: 0.9153
# Epoch 8/50
# 203/203 [==============================] - 68s 333ms/step - loss: 0.0646 - accuracy: 0.9826 - val_loss: 0.4360 - val_accuracy: 0.9048
# Epoch 9/50
# 203/203 [==============================] - 68s 334ms/step - loss: 0.0764 - accuracy: 0.9824 - val_loss: 1.6821 - val_accuracy: 0.7146
# Epoch 10/50
# 203/203 [==============================] - 68s 334ms/step - loss: 0.1091 - accuracy: 0.9717 - val_loss: 0.3718 - val_accuracy: 0.9214
# Epoch 11/50
# 203/203 [==============================] - 67s 332ms/step - loss: 0.0740 - accuracy: 0.9829 - val_loss: 0.8092 - val_accuracy: 0.8306
# Epoch 12/50
# 203/203 [==============================] - 68s 334ms/step - loss: 0.0713 - accuracy: 0.9840 - val_loss: 0.2833 - val_accuracy: 0.9459
# Epoch 13/50
# 203/203 [==============================] - 68s 334ms/step - loss: 0.0551 - accuracy: 0.9871 - val_loss: 0.1915 - val_accuracy: 0.9626
# Epoch 14/50
# 203/203 [==============================] - 68s 335ms/step - loss: 0.0469 - accuracy: 0.9874 - val_loss: 0.2298 - val_accuracy: 0.9551
# Epoch 15/50
# 203/203 [==============================] - 68s 336ms/step - loss: 0.0325 - accuracy: 0.9933 - val_loss: 0.3802 - val_accuracy: 0.9241
# Epoch 16/50
# 203/203 [==============================] - 68s 335ms/step - loss: 0.0648 - accuracy: 0.9851 - val_loss: 0.2184 - val_accuracy: 0.9490
# Epoch 17/50
# 203/203 [==============================] - 68s 336ms/step - loss: 0.0295 - accuracy: 0.9935 - val_loss: 0.2157 - val_accuracy: 0.9544
# Epoch 18/50
# 203/203 [==============================] - 68s 333ms/step - loss: 0.0432 - accuracy: 0.9901 - val_loss: 0.2791 - val_accuracy: 0.9388
# Epoch 19/50
# 203/203 [==============================] - 68s 334ms/step - loss: 0.0259 - accuracy: 0.9939 - val_loss: 0.2816 - val_accuracy: 0.9483
# Epoch 20/50
# 203/203 [==============================] - 67s 332ms/step - loss: 0.0563 - accuracy: 0.9879 - val_loss: 0.6438 - val_accuracy: 0.8697
# Epoch 21/50
# 203/203 [==============================] - 68s 334ms/step - loss: 0.0742 - accuracy: 0.9831 - val_loss: 0.6254 - val_accuracy: 0.8769
# Epoch 22/50
# 203/203 [==============================] - 68s 333ms/step - loss: 0.0346 - accuracy: 0.9920 - val_loss: 0.2857 - val_accuracy: 0.9446
# Epoch 23/50
# 203/203 [==============================] - 68s 334ms/step - loss: 0.0482 - accuracy: 0.9894 - val_loss: 0.1925 - val_accuracy: 0.9534
# Epoch 24/50
# 203/203 [==============================] - 68s 335ms/step - loss: 0.0178 - accuracy: 0.9957 - val_loss: 0.1469 - val_accuracy: 0.9656
# Epoch 25/50
# 203/203 [==============================] - 68s 334ms/step - loss: 0.0360 - accuracy: 0.9933 - val_loss: 0.2798 - val_accuracy: 0.9371
# Epoch 26/50
# 203/203 [==============================] - 68s 337ms/step - loss: 0.0372 - accuracy: 0.9910 - val_loss: 1.4776 - val_accuracy: 0.7983
# Epoch 27/50
# 203/203 [==============================] - 68s 334ms/step - loss: 0
# Epoch 49/50
# 203/203 [==============================] - 68s 337ms/step - loss: 0.0127 - accuracy: 0.9981 - val_loss: 0.2477 - val_accuracy: 0.9473
# Epoch 50/50
# 203/203 [==============================] - 68s 337ms/step - loss: 0.0256 - accuracy: 0.9957 - val_loss: 0.3555 - val_accuracy: 0.9480

# %% [markdown]
# ### Xception Model Accuracy and loss visualization

# %%
# Plot training & validation accuracy values
fig, ax = plt.subplots(1,1)
plt.plot(H.history["accuracy"])
plt.plot(H.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
# Plot training & validation loss values
fig, ax = plt.subplots(1,1)
plt.plot(H.history['loss'])
plt.plot(H.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %% [markdown]
# ### Model evaluation with classification report and confusion matrix

# %%
y_pred = np.argmax(model.predict(X_test,batch_size=1), axis=1) 

print('Classification Report')
y_classes = [np.argmax(y, axis=None, out=None) for y in y_test]
report = classification_report(y_classes, y_pred)
print(report)

plt.figure(figsize=(30,30))
cm = confusion_matrix(y_classes, y_pred)
_=sns.heatmap(cm.T, annot=True, fmt='d', cbar=True, square=True)
plt.xlabel('Truth')
plt.ylabel('Predicted')
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.98      0.88      0.93        60
#            1       0.97      0.97      0.97        60
#            2       0.94      0.98      0.96        60
#            3       0.88      0.95      0.91        60
#            4       0.96      0.88      0.92        60
#            5       0.96      0.92      0.94        60
#            6       0.95      0.90      0.92        60
#            7       0.97      0.95      0.96        60
#            8       0.97      1.00      0.98        60
#            9       0.92      1.00      0.96        60
#           10       1.00      0.97      0.98        60
#           11       0.94      0.98      0.96        60
#           12       0.98      1.00      0.99        60
#           13       0.97      1.00      0.98        60
#           14       0.98      0.95      0.97        60
#           15       0.92      1.00      0.96        60
#           16       1.00      0.97      0.98        60
#           17       1.00      1.00      1.00        60
#           18       0.95      0.95      0.95        60
#           19       1.00      1.00      1.00        60
#           20       0.98      0.97      0.97        60
#           21       0.74      0.98      0.84        60
#           22       1.00      0.87      0.93        60
#           23       0.98      0.97      0.97        60
#           24       0.98      0.87      0.92        60
#           25       0.94      0.98      0.96        60
#           26       0.98      0.97      0.97        60
#           27       0.94      0.98      0.96        60
#           28       0.75      0.95      0.84        60
#           29       0.91      0.87      0.89        60
#           30       0.87      0.77      0.81        60
#           31       0.85      1.00      0.92        60
#           32       0.97      0.97      0.97        60
#           33       0.98      0.88      0.93        60
#           34       0.98      1.00      0.99        60
#           35       0.94      0.97      0.95        60
#           36       1.00      1.00      1.00        60
#           37       0.98      0.98      0.98        60
#           38       1.00      0.97      0.98        60
#           39       0.98      0.98      0.98        60
#           40       1.00      1.00      1.00        60
#           41       0.98      1.00      0.99        60
#           42       0.96      0.73      0.83        60
#           43       0.83      1.00      0.91        60
#           44       1.00      0.82      0.90        60
#           45       1.00      0.73      0.85        60
#           46       0.91      1.00      0.95        60
#           47       1.00      1.00      1.00        60
#           48       1.00      1.00      1.00        60
#
#     accuracy                           0.95      2940
#    macro avg       0.95      0.95      0.95      2940
# weighted avg       0.95      0.95      0.95      2940
# Text(249.0, 0.5, 'Predicted')

# %%
#model.save('./BDSL_xception_model.hdf5')
